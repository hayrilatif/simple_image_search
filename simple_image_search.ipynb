# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import zipfile
import matplotlib.pyplot as plt

# %%
dataset=tfds.load("cifar10",split="train")
dataset_test=tfds.load("cifar10",split="test")
# Out:
# Downloading and preparing dataset 162.17 MiB (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/3.0.2.incompleteZATC4M/cifar10-train.tfrecord*...:   0%|          …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/3.0.2.incompleteZATC4M/cifar10-test.tfrecord*...:   0%|          |…
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %%
def transformation(x):
  x_t=((tf.cast(x["image"],tf.float32)/255.)-0.5)*2.
  return (x_t,x_t)

train_dataset=dataset.map(transformation).batch(32).prefetch(tf.data.AUTOTUNE)
test_dataset=dataset_test.map(transformation).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
def conv_block(count,size,act):
  def func(x):
    c=tf.keras.layers.Conv2D(count,size,padding="same")(x)
    p=tf.keras.layers.MaxPooling2D()(c)
    a=tf.keras.layers.Activation(act)(p)
    return a
  return func

def conv_block_up(count,size,act):
  def func(x):
    c=tf.keras.layers.Conv2D(count,size,padding="same")(x)
    p=tf.keras.layers.UpSampling2D()(c)
    a=tf.keras.layers.Activation(act)(p)
    return a
  return func

# %%
def get_encoder():
  inp=tf.keras.layers.Input((32,32,3))

  b1=conv_block(32,5,"leaky_relu")(inp)#16
  b2=conv_block(32,5,"leaky_relu")(b1)#8
  b3=conv_block(64,4,"leaky_relu")(b2)#4
  b4=conv_block(64,2,"leaky_relu")(b3)#2
  b4=conv_block(128,2,"leaky_relu")(b4)#1

  return tf.keras.models.Model(inp,b4)

def get_decoder():
  inp=tf.keras.layers.Input((1,1,128))

  u1=conv_block_up(128,1,"leaky_relu")(inp)
  u2=conv_block_up(64,2,"leaky_relu")(u1)
  u3=conv_block_up(64,4,"leaky_relu")(u2)
  u4=conv_block_up(32,5,"leaky_relu")(u3)
  u5=conv_block_up(32,5,"leaky_relu")(u4)

  c1=tf.keras.layers.Conv2D(3,1,activation="tanh")(u5)

  return tf.keras.models.Model(inp,c1)

# %%
encoder=get_encoder()
decoder=get_decoder()

# %%
ae=tf.keras.models.Sequential([tf.keras.layers.InputLayer((32,32,3)),
                               encoder,
                               decoder])

ae.compile(loss="mse",optimizer=tf.keras.optimizers.Adam())

# %%
history=ae.fit(train_dataset,validation_data=test_dataset,epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 14s 7ms/step - loss: 0.0867 - val_loss: 0.0673
# Epoch 2/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0602 - val_loss: 0.0558
# Epoch 3/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0532 - val_loss: 0.0507
# Epoch 4/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0496 - val_loss: 0.0488
# Epoch 5/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0467 - val_loss: 0.0470
# Epoch 6/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0449 - val_loss: 0.0449
# Epoch 7/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0436 - val_loss: 0.0437
# Epoch 8/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0425 - val_loss: 0.0416
# Epoch 9/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0414 - val_loss: 0.0422
# Epoch 10/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0407 - val_loss: 0.0416
# Epoch 11/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0400 - val_loss: 0.0400
# Epoch 12/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0395 - val_loss: 0.0397
# Epoch 13/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0389 - val_loss: 0.0395
# Epoch 14/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0384 - val_loss: 0.0388
# Epoch 15/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0379 - val_loss: 0.0375
# Epoch 16/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0376 - val_loss: 0.0374
# Epoch 17/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0374 - val_loss: 0.0371
# Epoch 18/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0370 - val_loss: 0.0371
# Epoch 19/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0367 - val_loss: 0.0368
# Epoch 20/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0364 - val_loss: 0.0371
# Epoch 21/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0361 - val_loss: 0.0365
# Epoch 22/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0359 - val_loss: 0.0366
# Epoch 23/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0357 - val_loss: 0.0360
# Epoch 24/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0354 - val_loss: 0.0359
# Epoch 25/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0353 - val_loss: 0.0354
# Epoch 26/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0350 - val_loss: 0.0349
# Epoch 27/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0349 - val_loss: 0.0350
# Epoch 28/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0348 - val_loss: 0.0348
# Epoch 29/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0345 - val_loss: 0.0347
# Epoch 30/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0345 - val_loss: 0.0353
# Epoch 31/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0343 - val_loss: 0.0350
# Epoch 32/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0341 - val_loss: 0.0343
# Epoch 33/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0340 - val_loss: 0.0342
# Epoch 34/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0339 - val_loss: 0.0342
# Epoch 35/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0337 - val_loss: 0.0339
# Epoch 36/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0336 - val_loss: 0.0341
# Epoch 37/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0334 - val_loss: 0.0334
# Epoch 38/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0334 - val_loss: 0.0341
# Epoch 39/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0332 - val_loss: 0.0340
# Epoch 40/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0332 - val_loss: 0.0338
# Epoch 41/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0330 - val_loss: 0.0337
# Epoch 42/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0329 - val_loss: 0.0337
# Epoch 43/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0328 - val_loss: 0.0337
# Epoch 44/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0328 - val_loss: 0.0330
# Epoch 45/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0326 - val_loss: 0.0329
# Epoch 46/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0325 - val_loss: 0.0329
# Epoch 47/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0324 - val_loss: 0.0328
# Epoch 48/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0324 - val_loss: 0.0327
# Epoch 49/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0323 - val_loss: 0.0324
# Epoch 50/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0322 - val_loss: 0.0322
# Epoch 51/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0321 - val_loss: 0.0324
# Epoch 52/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0321 - val_loss: 0.0322
# Epoch 53/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0320 - val_loss: 0.0333
# Epoch 54/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0319 - val_loss: 0.0334
# Epoch 55/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0318 - val_loss: 0.0329
# Epoch 56/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0318 - val_loss: 0.0323
# Epoch 57/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0316 - val_loss: 0.0323
# Epoch 58/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0315 - val_loss: 0.0324
# Epoch 59/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0315 - val_loss: 0.0321
# Epoch 60/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0314 - val_loss: 0.0321
# Epoch 61/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0314 - val_loss: 0.0321
# Epoch 62/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0313 - val_loss: 0.0321
# Epoch 63/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0314 - val_loss: 0.0317
# Epoch 64/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0313 - val_loss: 0.0319
# Epoch 65/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0312 - val_loss: 0.0317
# Epoch 66/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0312 - val_loss: 0.0317
# Epoch 67/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0311 - val_loss: 0.0316
# Epoch 68/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0311 - val_loss: 0.0315
# Epoch 69/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0310 - val_loss: 0.0314
# Epoch 70/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0310 - val_loss: 0.0316
# Epoch 71/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0310 - val_loss: 0.0311
# Epoch 72/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0308 - val_loss: 0.0311
# Epoch 73/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0309 - val_loss: 0.0312
# Epoch 74/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0308 - val_loss: 0.0313
# Epoch 75/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0308 - val_loss: 0.0309
# Epoch 76/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0307 - val_loss: 0.0310
# Epoch 77/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0307 - val_loss: 0.0308
# Epoch 78/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0306 - val_loss: 0.0309
# Epoch 79/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0306 - val_loss: 0.0309
# Epoch 80/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0305 - val_loss: 0.0306
# Epoch 81/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0305 - val_loss: 0.0305
# Epoch 82/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0305 - val_loss: 0.0306
# Epoch 83/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0304 - val_loss: 0.0306
# Epoch 84/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0304 - val_loss: 0.0306
# Epoch 85/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0304 - val_loss: 0.0306
# Epoch 86/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0304 - val_loss: 0.0307
# Epoch 87/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0303 - val_loss: 0.0305
# Epoch 88/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0303 - val_loss: 0.0307
# Epoch 89/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0302 - val_loss: 0.0305
# Epoch 90/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0303 - val_loss: 0.0307
# Epoch 91/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0302 - val_loss: 0.0307
# Epoch 92/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0302 - val_loss: 0.0308
# Epoch 93/100
#  556/1563 [=========>....................] - ETA: 6s - loss: 0.0301
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-a6746e503e31> in <cell line: 1>()
# ----> 1 history=ae.fit(train_dataset,validation_data=test_dataset,epochs=100)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     136   # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137   bound_args = function.function_type.bind(*args, **kwargs)
# --> 138   flat_inputs = function.function_type.unpack_inputs(bound_args)
#     139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in unpack_inputs(self, bound_parameters)
#     389     for p in sorted_parameters:
#     390       flat.extend(
# --> 391           p.type_constraint.to_tensors(bound_parameters.arguments[p.name])
#     392       )
#     393
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/type_spec.py in to_tensors(self, value)
#     250
#     251     tensors = []
# --> 252     nest.map_structure(
#     253         lambda spec, v: tensors.extend(spec.to_tensors(v)),
#     254         self._component_specs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1064   """
#    1065   if modality == Modality.CORE:
# -> 1066     return _tf_core_map_structure(func, *structure, **kwargs)
#    1067   elif modality == Modality.DATA:
#    1068     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1102   entries = zip(*flat_structure)
#    1103
# -> 1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
#    1106       [func(*x) for x in entries],
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     918           % (len(flat_structure), len(flat_sequence), structure, flat_sequence)
#     919       )
# --> 920   return sequence_fn(structure, packed)
#     921
#     922
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in sequence_like(instance, args)
#     243     # in the proxy type.
#     244     return type(instance)(sequence_like(instance.__wrapped__, args))
# --> 245   elif isinstance(instance, CustomNestProtocol):
#     246     metadata = instance.__tf_flatten__()[0]
#     247     return instance.__tf_unflatten__(metadata, tuple(args))
#
# /usr/lib/python3.10/typing.py in __instancecheck__(cls, instance)
#    1500
#    1501         if ((not getattr(cls, '_is_protocol', False) or
# -> 1502                 _is_callable_members_only(cls)) and
#    1503                 issubclass(instance.__class__, cls)):
#    1504             return True
#
# /usr/lib/python3.10/typing.py in _is_callable_members_only(cls)
#    1425 def _is_callable_members_only(cls):
#    1426     # PEP 544 prohibits using issubclass() with protocols that have non-method members.
# -> 1427     return all(callable(getattr(cls, attr, None)) for attr in _get_protocol_attrs(cls))
#    1428
#    1429
#
# /usr/lib/python3.10/typing.py in <genexpr>(.0)
#    1425 def _is_callable_members_only(cls):
#    1426     # PEP 544 prohibits using issubclass() with protocols that have non-method members.
# -> 1427     return all(callable(getattr(cls, attr, None)) for attr in _get_protocol_attrs(cls))
#    1428
#    1429
#
# KeyboardInterrupt:

# %%
plt.plot(history.history["val_loss"],label="val_loss")
plt.plot(history.history["loss"],label="loss")
plt.legend()

# %%
encoder.save("simple_encoder_v1")
decoder.save("simple_decoder_v1")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
with zipfile.ZipFile("simple_encoder_v1.zip","w") as zf:
  zf.write("simple_encoder_v1")

with zipfile.ZipFile("simple_decoder_v1.zip","w") as zf:
  zf.write("simple_decoder_v1")

# %%
encoder_tflite=tf.lite.TFLiteConverter.from_keras_model(encoder)
decoder_tflite=tf.lite.TFLiteConverter.from_keras_model(decoder)

# %%
encoder_tflite.optimizations=[tf.lite.Optimize.DEFAULT]
decoder_tflite.optimizations=[tf.lite.Optimize.DEFAULT]

# %%
encoder_tfl_model=encoder_tflite.convert()
decoder_tfl_model=decoder_tflite.convert()

# %%
with open("simple_encoder_quantized_v1.tfl","wb") as f:
  f.write(encoder_tfl_model)

with open("simple_decoder_quantized_v1.tfl","wb") as f:
  f.write(decoder_tfl_model)

# %%
tf.lite.Interpreter("content/simple_encoder_quantized_v1.tfl")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-79888ee9197b> in <cell line: 1>()
# ----> 1 tf.lite.Interpreter("content/simple_encoder_quantized_v1.tfl")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/interpreter.py in __init__(self, model_path, model_content, experimental_delegates, num_threads, experimental_op_resolver_type, experimental_preserve_all_tensors, experimental_disable_delegate_clustering)
#     462           x for x in self._custom_op_registerers if not isinstance(x, str)
#     463       ]
# --> 464       self._interpreter = _interpreter_wrapper.CreateWrapperFromFile(
#     465           model_path,
#     466           op_resolver_id,
#
# ValueError: Could not open 'content/simple_encoder_quantized_v1.tfl'.
